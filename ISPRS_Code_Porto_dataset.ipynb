# %%
from collections import OrderedDict
from torch import Tensor
import re
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.checkpoint as cp
from collections import OrderedDict
from torch import Tensor
from typing import Type, Any, Callable, Union, List, Optional
import glob
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from torch import optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Subset,DataLoader
import torchvision.transforms as transforms
import torchvision
import random
from google.colab import files
from sklearn.metrics import  confusion_matrix
from sklearn.model_selection import ShuffleSplit
import cv2
from google.colab.patches import cv2_imshow
from scipy.ndimage import distance_transform_edt
from torch.autograd import Variable
import skimage.segmentation
import skimage.io
import skimage
from scipy.optimize import linear_sum_assignment
import skimage.segmentation
import matplotlib.pyplot as plt
import skimage.io
import skimage.segmentation
from skimage import feature
from skimage import filters
import copy
import torchvision
from collections import OrderedDict
import math
import imageio
from skimage.color import rgb2gray

# %%
p=cv2.imread('/content/drive/MyDrive/Porto Dataset/gt.png')

# %%
h,w,c=p.shape

# %%
print(h,w,c)
# Out:
# 14388 16747 3

# %%
##########################    Dataloading    ########################

# %%
def randomHueSaturationValue(
    image,
    hue_shift_limit=(-40, 40),
    sat_shift_limit=(-10, 10),
    val_shift_limit=(-20, 20),
    u=0.5,
):
    if np.random.random() < u:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(image)
        hue_shift = np.random.randint(
            hue_shift_limit[0], hue_shift_limit[1] + 1)
        hue_shift = np.uint8(hue_shift)
        h += hue_shift
        sat_shift = np.random.uniform(sat_shift_limit[0], sat_shift_limit[1])
        s = cv2.add(s, sat_shift)
        val_shift = np.random.uniform(val_shift_limit[0], val_shift_limit[1])
        v = cv2.add(v, val_shift)
        image = cv2.merge((h, s, v))
        image = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

    return image


def randomShiftScaleRotate(
    image,
    mask,
    shift_limit=(-0.1, 0.1),
    scale_limit=(-0.1, 0.1),
    aspect_limit=(-0.1, 0.1),
    rotate_limit=(-0, 0),
    borderMode=cv2.BORDER_CONSTANT,
    u=0.5,
):
    if np.random.random() < u:
        height, width, channel = image.shape

        angle = np.random.uniform(rotate_limit[0], rotate_limit[1])
        scale = np.random.uniform(1 + scale_limit[0], 1 + scale_limit[1])
        aspect = np.random.uniform(1 + aspect_limit[0], 1 + aspect_limit[1])
        sx = scale * aspect / (aspect ** 0.5)
        sy = scale / (aspect ** 0.5)
        dx = round(np.random.uniform(shift_limit[0], shift_limit[1]) * width)
        dy = round(np.random.uniform(shift_limit[0], shift_limit[1]) * height)

        cc = np.math.cos(angle / 180 * np.math.pi) * sx
        ss = np.math.sin(angle / 180 * np.math.pi) * sy
        rotate_matrix = np.array([[cc, -ss], [ss, cc]])

        box0 = np.array([[0, 0], [width, 0], [width, height], [0, height]])
        box1 = box0 - np.array([width / 2, height / 2])
        box1 = np.dot(box1, rotate_matrix.T) + np.array(
            [width / 2 + dx, height / 2 + dy]
        )

        box0 = box0.astype(np.float32)
        box1 = box1.astype(np.float32)
        mat = cv2.getPerspectiveTransform(box0, box1)
        image = cv2.warpPerspective(
            image,
            mat,
            (width, height),
            flags=cv2.INTER_NEAREST,
            borderMode=borderMode,
            borderValue=(0, 0, 0),
        )
        mask = cv2.warpPerspective(
            mask,
            mat,
            (width, height),
            flags=cv2.INTER_NEAREST,
            borderMode=borderMode,
            borderValue=(0, 0, 0),
        )

    return image, mask


def randomHorizontalFlip(image, mask, u=0.5):
    if np.random.random() < u:
        image = cv2.flip(image, 1)
        mask = cv2.flip(mask, 1)

    return image, mask


def randomVerticleFlip(image, mask, u=0.5):
    if np.random.random() < u:
        image = cv2.flip(image, 0)
        mask = cv2.flip(mask, 0)

    return image, mask


def randomRotate90(image, mask, u=0.5):
    if np.random.random() < u:
        image = np.rot90(image)
        mask = np.rot90(mask)

    return image, mask

# %%
def extract_patches_2d(img,patch_shape,step=[1.0,1.0],batch_first=False):
    patch_H, patch_W = patch_shape[0], patch_shape[1]
    if(img.size(2)<patch_H):
        num_padded_H_Top = (patch_H - img.size(2))//2
        num_padded_H_Bottom = patch_H - img.size(2) - num_padded_H_Top
        padding_H = nn.ConstantPad2d((0,0,num_padded_H_Top,num_padded_H_Bottom),0)
        img = padding_H(img)
    if(img.size(3)<patch_W):
        num_padded_W_Left = (patch_W - img.size(3))//2
        num_padded_W_Right = patch_W - img.size(3) - num_padded_W_Left
        padding_W = nn.ConstantPad2d((num_padded_W_Left,num_padded_W_Right,0,0),0)
        img = padding_W(img)
    step_int = [0,0]
    step_int[0] = int(patch_H*step[0]) if(isinstance(step[0], float)) else step[0]
    step_int[1] = int(patch_W*step[1]) if(isinstance(step[1], float)) else step[1]
    patches_fold_H = img.unfold(2, patch_H, step_int[0])
    if((img.size(2) - patch_H) % step_int[0] != 0):
        patches_fold_H = torch.cat((patches_fold_H,img[:,:,-patch_H:,].permute(0,1,3,2).unsqueeze(2)),dim=2)
    patches_fold_HW = patches_fold_H.unfold(3, patch_W, step_int[1])
    if((img.size(3) - patch_W) % step_int[1] != 0):
        patches_fold_HW = torch.cat((patches_fold_HW,patches_fold_H[:,:,:,-patch_W:,:].permute(0,1,2,4,3).unsqueeze(3)),dim=3)
    patches = patches_fold_HW.permute(2,3,0,1,4,5)
    patches = patches.reshape(-1,img.size(0),img.size(1),patch_H,patch_W)
    if(batch_first):
        patches = patches.permute(1,0,2,3,4)
    return patches

def reconstruct_from_patches_2d(patches,img_shape,step=[1.0,1.0],batch_first=False):
    if(batch_first):
        patches = patches.permute(1,0,2,3,4)
    patch_H, patch_W = patches.size(3), patches.size(4)
    img_size = (patches.size(1), patches.size(2),max(img_shape[0], patch_H), max(img_shape[1], patch_W))
    step_int = [0,0]
    step_int[0] = int(patch_H*step[0]) if(isinstance(step[0], float)) else step[0]
    step_int[1] = int(patch_W*step[1]) if(isinstance(step[1], float)) else step[1]
    nrow, ncol = 1 + (img_size[-2] - patch_H)//step_int[0], 1 + (img_size[-1] - patch_W)//step_int[1]
    r_nrow = nrow + 1 if((img_size[2] - patch_H) % step_int[0] != 0) else nrow
    r_ncol = ncol + 1 if((img_size[3] - patch_W) % step_int[1] != 0) else ncol
    patches = patches.reshape(r_nrow,r_ncol,img_size[0],img_size[1],patch_H,patch_W)
    img = torch.zeros(img_size, device = patches.device)
    overlap_counter = torch.zeros(img_size, device = patches.device)
    for i in range(nrow):
        for j in range(ncol):
            img[:,:,i*step_int[0]:i*step_int[0]+patch_H,j*step_int[1]:j*step_int[1]+patch_W] += patches[i,j,]
            overlap_counter[:,:,i*step_int[0]:i*step_int[0]+patch_H,j*step_int[1]:j*step_int[1]+patch_W] += 1
    if((img_size[2] - patch_H) % step_int[0] != 0):
        for j in range(ncol):
            img[:,:,-patch_H:,j*step_int[1]:j*step_int[1]+patch_W] += patches[-1,j,]
            overlap_counter[:,:,-patch_H:,j*step_int[1]:j*step_int[1]+patch_W] += 1
    if((img_size[3] - patch_W) % step_int[1] != 0):
        for i in range(nrow):
            img[:,:,i*step_int[0]:i*step_int[0]+patch_H,-patch_W:] += patches[i,-1,]
            overlap_counter[:,:,i*step_int[0]:i*step_int[0]+patch_H,-patch_W:] += 1
    if((img_size[2] - patch_H) % step_int[0] != 0 and (img_size[3] - patch_W) % step_int[1] != 0):
        img[:,:,-patch_H:,-patch_W:] += patches[-1,-1,]
        overlap_counter[:,:,-patch_H:,-patch_W:] += 1
    img /= overlap_counter
    if(img_shape[0]<patch_H):
        num_padded_H_Top = (patch_H - img_shape[0])//2
        num_padded_H_Bottom = patch_H - img_shape[0] - num_padded_H_Top
        img = img[:,:,num_padded_H_Top:-num_padded_H_Bottom,]
    if(img_shape[1]<patch_W):
        num_padded_W_Left = (patch_W - img_shape[1])//2
        num_padded_W_Right = patch_W - img_shape[1] - num_padded_W_Left
        img = img[:,:,:,num_padded_W_Left:-num_padded_W_Right]
    return img

# %%
def image_generator(image_path,labels_path):
    # %mkdir '/content/Images'
    # %mkdir '/content/Labels'

    im_path='/content/Images'
    label_path='/content/Labels'
    image=np.array(cv2.imread(image_path))
    label=cv2.imread(labels_path)
    image=torch.from_numpy(image)
    label=torch.from_numpy(label[:,:,0])
    label=label.unsqueeze(2)
    image=image.permute(2,0,1).unsqueeze(0)
    label=label.permute(2,0,1).unsqueeze(0)
    images=extract_patches_2d(image,(512,512),step=[1.0,1.0],batch_first=True)
    labels=extract_patches_2d(label,(512,512),step=[1.0,1.0],batch_first=True)
    for j in range(images.shape[1]):
      a=images[0,j,:,:,:].permute(1,2,0)
      b=labels[0,j,:,:,:].permute(1,2,0)
      a=np.array(a)
      b=np.array(b, dtype='uint8')
      img_pth=str(1) + '_' + str(j) + '_' + 'image.png'
      lbl_pth=str(1) + '_' + str(j) + '_' + 'label.png'
      final_image_path=os.path.join(im_path,img_pth)
      final_label_path=os.path.join(label_path,lbl_pth)
      cv2.imwrite(final_image_path,a)
      imageio.imwrite(final_label_path,b[:,:,0])

# %%
image_generator('/content/drive/MyDrive/Porto Dataset/porto_global_satellite_image.png',
                '/content/drive/MyDrive/Porto Dataset/gt.png')

# %%
folder_data = glob.glob("/content/Images*/**.png")
folder_mask = glob.glob("/content/Labels*/**.png")
folder_data.sort()
folder_mask.sort()

# split these path using a certain percentage
len_data = len(folder_data)
print(len_data)
train_size = 0.80
test_size = 0.20


train_image_paths = folder_data[:int(len_data*train_size)]
test_image_paths = folder_data[int(len_data*(train_size)):]



train_mask_paths = folder_mask[:int(len_data*train_size)]
test_mask_paths = folder_mask[int(len_data*(train_size)):]



class CustomDataset(Dataset):
    def __init__(self, image_paths, target_paths):   # initial logic happens like transform

        self.image_paths = image_paths
        # self.image_paths.sort()
        self.target_paths = target_paths
        # self.target_paths.sort()
        self.transforms = transforms.ToTensor()

    def __getitem__(self, index):

        image = cv2.imread(self.image_paths[index])
        mask = cv2.imread(self.target_paths[index])
        image = self.transforms(image[:,:,:])
        mask = self.transforms(mask[:,:,0:1])


        # mask=torch.rot90(mask, 1, [1,2])


        #resize:
        #image=cv2.resize(image, (256,256))
        #mask=cv2.resize(mask ,(256,256), interpolation=cv2.INTER_NEAREST)
        #numpy-torch:



        # t_image=image/255.0
        #mask=mask/255.0

        return image, mask

    def __len__(self):  # return count of sample we have

        return len(self.image_paths)


train_dataset = CustomDataset(train_image_paths, train_mask_paths)
train_dl = torch.utils.data.DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)

test_dataset = CustomDataset(test_image_paths, test_mask_paths)
test_dl = torch.utils.data.DataLoader(test_dataset, batch_size=4, shuffle=False, num_workers=2)

print(len(train_dataset))
print(len(test_dataset))
# Out:
# 957
# 765
# 192

# %%
a,b=train_dataset[95]

# %%
b.shape
# Out:
# torch.Size([1, 512, 512])

# %%
##########################    Main model    ########################

# %%
def conv3x3(in_planes: int, out_planes: int, stride: int = 1, groups: int = 1, dilation: int = 1) -> nn.Conv2d:
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=dilation, groups=groups, bias=False, dilation=dilation)


def conv1x1(in_planes: int, out_planes: int, stride: int = 1) -> nn.Conv2d:
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)

# %%
class Upsample(nn.Module):
    """ nn.Upsample is deprecated """

    def __init__(self, scale_factor, mode="bilinear"):
        super(Upsample, self).__init__()
        self.scale_factor = scale_factor
        self.mode = mode

    def forward(self, x):
        x = F.interpolate(x, scale_factor=self.scale_factor, mode=self.mode, align_corners=True, recompute_scale_factor=True)
        return x

# %%
# Index Pooling
class pool(nn.Module):
  def __init__(self,channels):
    super(pool, self).__init__()
    self.channels=channels
    self.weight1 = torch.zeros((channels,1,2,2)).cuda()
    self.weight2 = torch.zeros((channels,1,2,2)).cuda()
    self.weight3 = torch.zeros((channels,1,2,2)).cuda()
    self.weight4 = torch.zeros((channels,1,2,2)).cuda()
    self.weight1[:,:,0,0]=1
    self.weight2[:,:,0,1]=1
    self.weight3[:,:,1,0]=1
    self.weight4[:,:,1,1]=1
  def forward(self, x):
    with torch.no_grad():
         x1=F.conv2d(x, self.weight1,stride=2,groups=self.channels, bias=None)
         x2=F.conv2d(x, self.weight2,stride=2,groups=self.channels, bias=None)
         x3=F.conv2d(x, self.weight3,stride=2,groups=self.channels, bias=None)
         x4=F.conv2d(x, self.weight4,stride=2,groups=self.channels, bias=None)
    return x1,x2,x3,x4

# %%
#DAMIP Module
class attn_pool(nn.Module):
    def __init__(self,feature_channels):
       super(attn_pool, self).__init__()
       self.pool1=pool(feature_channels)
       self.pool2=pool(1)
       self.conv1 = nn.Conv2d(feature_channels*4, 2*feature_channels, kernel_size=1, stride=1, bias=False)
       self.conv2 = nn.Conv2d(2*feature_channels,2*feature_channels,kernel_size=7,stride=1,padding=3)
       self.bn2 = nn.BatchNorm2d(2*feature_channels)
       self.a1=nn.Parameter(torch.Tensor(1))
       self.a2=nn.Parameter(torch.Tensor(1))
       self.a3=nn.Parameter(torch.Tensor(1))
       self.a4=nn.Parameter(torch.Tensor(1))
    def forward(self,map,feature):
        feature1,feature2,feature3,feature4=self.pool1(feature)
        map1,map2,map3,map4=self.pool2(map)

        fm1 = self.a1*feature1 + feature1*map1
        fm2 = self.a2*feature2 + feature2*map2
        fm3 = self.a3*feature3 + feature3*map3
        fm4 = self.a4*feature4 + feature4*map4

        mat=torch.cat((fm1,fm2,fm3,fm4),1)
        mat=self.conv1(mat)
        mat=F.relu(self.bn2(self.conv2(mat)))
        return mat

# %%
# DPGM Module
class dsup(nn.Module):
  def __init__(self,input_channels):
    super(dsup,self).__init__()
    self.conv1=conv3x3(input_channels,input_channels//2)
    self.bn1=nn.BatchNorm2d(input_channels//2)
    self.conv2=conv3x3(input_channels//2,32)
    self.conv3=nn.Conv2d(32,1,kernel_size=3,stride=1,padding=1)
  def forward(self,x):
    x=F.relu(self.bn1(self.conv1(x)))
    x=self.conv2(x)
    x=self.conv3(x)
    return torch.sigmoid(x)

# %%
# Dilated Convolutional Block
class conv_enc(nn.Module):
  def __init__(self,in_channels,out_channels,dil):
    super(conv_enc,self).__init__()
    self.conv1 = conv1x1(in_channels,in_channels)
    self.bn1 = nn.BatchNorm2d(in_channels)
    self.conv2 = conv3x3(in_channels,in_channels,dilation=dil)
    self.bn2 = nn.BatchNorm2d(in_channels)
    self.conv3 = conv1x1(in_channels,out_channels)
    self.bn3 = nn.BatchNorm2d(out_channels)
    self.conv4 = conv3x3(out_channels,out_channels,dilation=dil)
    self.bn4 = nn.BatchNorm2d(out_channels)
    # input dimension matching
    self.conv0 = conv1x1(in_channels,out_channels)
  def forward(self,x):
    identity = self.conv0(x)

    x=F.relu(self.bn1(self.conv1(x)))
    x=F.relu(self.bn2(self.conv2(x)))
    x=F.relu(self.bn3(self.conv3(x)))
    x=self.bn4(self.conv4(x))

    return F.relu(x+identity)

# %%
# Feature Extractor. In paper we mention 4 blocks but in code we use 2 blocks
class enc(nn.Module):
  def __init__(self,input_channels,output_channels,dil):
    super(enc,self).__init__()
    self.conv1 = conv_enc(input_channels,output_channels,dil)
    self.conv2 = conv_enc(output_channels,output_channels,2*dil)
    self.dp_sup = dsup(output_channels)     # DPMG Module

  def forward(self,x):
    x1 = self.conv1(x)
    x1 = self.conv2(x1)
    x1_out = self.dp_sup(x1)
    return x1, x1_out

# %%
# DAMSCA Module
class kqcbam(nn.Module):
  def __init__(self,input_channels,scale_factor=2):
    super(kqcbam,self).__init__()
    self.conv1=nn.Conv2d(1,input_channels,kernel_size=1)
    self.gap=nn.AdaptiveAvgPool2d((1,1))
    self.upsample=Upsample(scale_factor)
  def forward(self,map,feature):
    f1=map*feature
    map2=self.conv1(map)
    map2=self.gap(map2)
    f2=torch.sigmoid(map2)*feature
    out=F.relu(f1+f2)
    return self.upsample(out)

# %%
# Decoder Module
class decoder(nn.Module):
  def __init__(self,input_channels):
    super(decoder,self).__init__()
    self.conv1=nn.ConvTranspose2d(input_channels,128,kernel_size=4,stride=2,padding=1)
    self.bn1=nn.BatchNorm2d(128)
    self.conv2=nn.Conv2d(128,64,3,stride=1,padding=1)
    self.bn2=nn.BatchNorm2d(64)
    self.conv3=nn.Conv2d(64,32,3,stride=1,padding=1)
    self.conv_out=nn.Conv2d(32,1,3,stride=1,padding=1)
  def forward(self,x):
    x=F.relu(self.bn1(self.conv1(x)))
    x=F.relu(self.bn2(self.conv2(x)))
    x=self.conv3(x)
    x=self.conv_out(x)
    return torch.sigmoid(x)

# %%
class dsmpnet(nn.Module):
  def __init__(self,input_channels):
    super(dsmpnet,self).__init__()
    self.conv1=nn.Conv2d(input_channels,64,kernel_size=7,stride=2,padding=3)
    self.bn1=nn.BatchNorm2d(64)

    self.pool1=attn_pool(64)
    self.pool2=attn_pool(128)

    self.path1=enc(64,64,1)
    self.path2=enc(128,128,2)
    self.path3=enc(256,256,4)

    self.cbm1=kqcbam(64,1)
    self.cbm2=kqcbam(128,2)
    self.cbm3=kqcbam(256,4)

    self.decoder=decoder(448)

  def forward(self,x):
    x=F.relu(self.bn1(self.conv1(x)))
    x1,x1_out=self.path1(x)
    x=self.pool1(x1_out,x)
    x2,x2_out=self.path2(x)
    x=self.pool2(x2_out,x)
    x3,x3_out=self.path3(x)

    x1=self.cbm1(x1_out,x1)
    x2=self.cbm2(x2_out,x2)
    x3=self.cbm3(x3_out,x3)
    x_out=torch.cat((x1,x2,x3),1)
    x_out=self.decoder(x_out)
    return x_out,x1_out,x2_out,x3_out

# %%
model=dsmpnet(3).cuda()

# %%
##########################    Loss function and performance metrics    ########################

# %%
#loss function
class dice_bce_loss(nn.Module):
    def __init__(self, batch=True):
        super(dice_bce_loss, self).__init__()
        self.batch = batch
        self.bce_loss = nn.BCELoss()

    def soft_dice_coeff(self, y_true, y_pred):
        smooth = 1.0  # may change
        if self.batch:
            i = torch.sum(y_true)
            j = torch.sum(y_pred)
            intersection = torch.sum(y_true * y_pred)
        else:
            i = y_true.sum(1).sum(1).sum(1)
            j = y_pred.sum(1).sum(1).sum(1)
            intersection = (y_true * y_pred).sum(1).sum(1).sum(1)
        score = (2. * intersection + smooth) / (i + j + smooth)
        # score = (intersection + smooth) / (i + j - intersection + smooth)#iou
        return score.mean()

    def soft_dice_loss(self, y_true, y_pred):
        loss = 1 - self.soft_dice_coeff(y_true, y_pred)
        return loss

    def __call__(self, y_pred, y_true):
        a = self.bce_loss(y_pred, y_true)
        b = self.soft_dice_loss(y_true, y_pred)
        return a + b

# %%
class gen_loss(nn.Module):
  def __init__(self,gamma=1.5,batch=True):
    super(gen_loss,self).__init__()
    self.bce_loss=nn.BCELoss()
    self.gamma=gamma

  def gen_dice(self,y_pred,y_true):
    epsilon=1e-8
    l1=abs(y_pred-y_true)**self.gamma
    y_pred_sqsum=torch.sum((y_pred*y_pred))
    y_true_sqsum=torch.sum((y_true*y_true))
    l1_sum=torch.sum(l1)
    score=(l1_sum + epsilon)/(y_pred_sqsum + y_true_sqsum )
    return score.mean()

  def __call__(self,y_pred,y_true):
    a=self.bce_loss(y_pred,y_true)
    b=self.gen_dice(y_pred,y_true)
    return a+b

# %%
def y_bce_loss(prediction1,prediction2,prediction3,prediction4,label):
    dice=gen_loss()
    loss1=dice(prediction1,label)
    label=torch.nn.functional.interpolate(label, size=(256,256), scale_factor=None, mode='nearest')
    loss2=dice(prediction2,label)
    label=torch.nn.functional.interpolate(label, size=(128,128), scale_factor=None, mode='nearest')
    loss3=dice(prediction3,label)
    label=torch.nn.functional.interpolate(label, size=(64,64), scale_factor=None, mode='nearest')
    loss4=dice(prediction4,label)
    loss=loss1+loss2+loss3+loss4
    return loss

# %%
# def per_class_loss(pred1,label):
#   dice=dice_bce_loss()
#   loss0=dice(label[:,0:1,:,:],pred1[:,0:1,:,:])
#   loss1=dice(label[:,1:2,:,:],pred1[:,1:2,:,:])
#   loss2=dice(label[:,2:3,:,:],pred1[:,2:3,:,:])
#   loss3=dice(label[:,3:4,:,:],pred1[:,3:4,:,:])
#   loss=loss1+loss2+loss3+loss0
#   return loss

def dice_multi_loss(pred1,pred2,pred3,pred4,label):
  dice=dice_bce_loss()
  loss0=dice(pred1,label)
  loss1=dice(pred2,label)
  loss2=dice(pred3,label)
  loss3=dice(pred4,label)
  loss=loss1+loss2+loss3+loss0
  return loss

# %%
class IoU(nn.Module):
    def __init__(self, threshold=0.5):
        super(IoU, self).__init__()
        self.threshold = threshold

    def forward(self, target, input):
        eps = 1e-10
        input_ = (input > self.threshold).data.float()
        target_ = (target > self.threshold).data.float()

        intersection = torch.clamp(input_ * target_, 0, 1)
        union = torch.clamp(input_ + target_, 0, 1)

        if torch.mean(intersection).lt(eps):
            return torch.Tensor([0., 0., 0., 0.])
        else:
            acc = torch.mean((input_ == target_).data.float())
            iou = torch.mean(intersection) / torch.mean(union)
            recall = torch.mean(intersection) / torch.mean(target_)
            precision = torch.mean(intersection) / torch.mean(input_)
            return torch.Tensor([acc, recall, precision, iou])
iou=IoU()

# %%
def dice_coeff(y_true,y_pred,batch=True):
        smooth = 1e-8  # may change
        if batch:
            i = torch.sum(y_true)
            j = torch.sum(y_pred)
            intersection = torch.sum(y_true * y_pred)
        else:
            i = y_true.sum(1).sum(1).sum(1)
            j = y_pred.sum(1).sum(1).sum(1)
            intersection = (y_true * y_pred).sum(1).sum(1).sum(1)
        score = (2. * intersection + smooth) / (i + j + smooth)
        # score = (intersection + smooth) / (i + j - intersection + smooth)#iou
        return score.mean()

# %%
##########################    Training and Testing    ########################

# %%
def train_one_epoch_net(model, train_dl, learn):
    opt = torch.optim.Adam(model.parameters(),lr=learn)
    running_loss_image=0.0
    metric_epoch=0.0
    dice_epoch=0.0
    for a,b in train_dl:
        a=a.float()
        label=b.float()
        #label_loss=b.type(torch.long)
        label_loss=b.type(torch.float)
        pred1,pred2,pred3,pred4=model(a.cuda())
        #pred1=output['out']
        loss=y_bce_loss(pred1,pred2,pred3,pred4,label_loss.cuda())
        opt.zero_grad()
        loss.backward()
        opt.step()
        running_loss_image += loss
        metric=iou(label_loss,pred1.detach().cpu())
        dice = dice_coeff(label_loss,pred1.detach().cpu())
        dice_epoch += dice
        metric_epoch += metric
    running_loss_image/=len(train_dl)
    metric_epoch /= len(train_dl)
    dice_epoch /= len(train_dl)
    return model, dice_epoch, metric_epoch, running_loss_image
    #return model, running_loss_image


def validate_one_epoch_net(model, val_dl):
    running_loss_image=0.0
    metric_epoch=0.0
    dice_epoch=0.0
    with torch.no_grad():
        for a,b in val_dl:
            a=a.float()
            label=b.float()
            #label_loss=b.type(torch.long)
            label_loss=b.type(torch.float)
            pred1,pred2,pred3,pred4=model(a.cuda())
            #pred1=output['out']
            loss=y_bce_loss(pred1,pred2,pred3,pred4,label_loss.cuda())
            running_loss_image += loss
            metric=iou(label_loss,pred1.detach().cpu())
            dice = dice_coeff(label_loss,pred1.detach().cpu())
            dice_epoch += dice
            metric_epoch += metric
    running_loss_image/=len(val_dl)
    metric_epoch /= len(val_dl)
    dice_epoch /= len(val_dl)
    return dice_epoch, metric_epoch, running_loss_image
    #return  running_loss_image

# %%
def train_epoches_net(model,train_dl,test_dl,epoches,learn,path):
    max_accuracy=0.0
    for i in range(epoches):
        model, dice_train, iou_train, loss_train=train_one_epoch_net(model,train_dl,learn)
        #dice_val,loss_validate=validate_one_epoch_covidnet(model,val_dl)
        dice_test, iou_test, loss_test=validate_one_epoch_net(model,test_dl)
        print('epoch finished' +" " + str(i+1))
        print(f'train_loss: {loss_train:.6f}, train_dice: {dice_train:.6f}, train_iou: {iou_train[3]:.6f}')
        #print(f'val_loss: {loss_validate:.6f} dice_val:{dice_val}')
        print(f'test_loss: {loss_test:.6f}, test_dice: {dice_test:.6f}, test_iou: {iou_test[3]:.6f}')
        print()
        if iou_test[3]>max_accuracy:
            max_accuracy=iou_test[3]
            path_final=os.path.join(path,
                                    f"epoch{i}_test_iou{iou_test[3]:.4f}")
            torch.save(model.state_dict(), path_final)
        # path_final=os.path.join(path,
        #                             f"epoch{i}_test_loss{loss_test:.4f}.pth")
        # torch.save(model.state_dict(), path_final)

# %%
# %mkdir tgrs
train_epoches_net(model,test_dl,test_dl,20,0.001,'/content/tgrs')

# %%
model.load_state_dict(torch.load('/content/tgrs/epoch18_test_iou0.6527'))

# %%
##########################    Performance metrics evaluation    ########################

# %%
test_dl = torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=2)
x,y,z=validate_one_epoch_net(model, test_dl)
print(x,y,z)

# %%
##########################    Output images geenration    ########################

# %%
def post_medical(prediction,label,im_height,im_width):
    prediction=(prediction>=0.5)*1.0
    label=(label>=0.5)*1.0
    pred=prediction-label
    pred_red=(pred==1.0)*1.0
    pred_blue=(pred==-1.0)*1.0
    final_pred=(prediction*label)*1.0 + 2*pred_blue + 3*pred_red
    x=torch.zeros((im_height,im_width,3))
    x[:,:,1]=(prediction*label)*255.0 + pred_red*191.0
    x[:,:,0]=pred_red*255.0 #+ (prediction*label)*255.0
    x[:,:,2]=pred_blue*255.0 + (prediction*label)*255.0
    return final_pred,pred_blue,pred_red,x

def predict_non_mlsa(model,data_dl,model_path=''):
  #%mkdir '/content/predict_colour_dir'
  #%mkdir '/content/label_dir'
  import os
  image_dir='/content/in1' # Directory of input images
  predict_colour_dir='/content/out' # output maps directory.
  label_dir='/content/label' # labels directory fixed in one file.
  model.load_state_dict(torch.load(model_path))
  model=model.cuda()
  count=1
  with torch.no_grad():
    for j, (a,b) in enumerate(data_dl):
      a=a.float()
      pred1=model(a.cuda())
      pred1=pred1.detach().cpu()
      a=a*255.0
      a=a.detach().cpu()
      for i in range(pred1.shape[0]):
        image=np.array(a[i,0:3,:,:].permute(1,2,0)).astype(np.uint8) #for RGB images
        pred=np.array(((pred1[i,0,:,:]>=0.5 +0)*255.0)).astype(np.uint8)
        _,_,_,x=post_medical(pred1[i,0,:,:], b[i,0,:,:],256,256) # image height and width might change
        x=np.array(x).astype(np.uint8)
        _,_,_,lab=post_medical(b[i,0,:,:],b[i,0,:,:],256,256) # image height and width might change
        lab=np.array(lab).astype(np.uint8)
        image_filename=os.path.join(image_dir, f"input_{count}.tif")
        pred_colour_filename=os.path.join(predict_colour_dir, f"colour_{count}.png")
        label_filename=os.path.join(label_dir, f"label_{count}.png")
        imageio.imsave(image_filename,image)
        cv2.imwrite(pred_colour_filename, x)
        cv2.imwrite(label_filename, lab)
        print("[DONE] predicted image: ", image_filename)
        print("[DONE] predicted image: ", pred_colour_filename)
        print("[DONE] predicted image: ", label_filename)
        count=count+1


def predict_mlsa(model,data_dl,model_path=''):
  # %mkdir '/content/drive/MyDrive/figures/porto/tip/pred1'
  # %mkdir '/content/drive/MyDrive/figures/porto/tip/pred2'
  # %mkdir '/content/drive/MyDrive/figures/porto/tip/pred3'
  # %mkdir '/content/drive/MyDrive/figures/porto/tip/pred4'
  # %mkdir '/content/drive/MyDrive/figures/porto/tip/label'
  # %mkdir '/content/drive/MyDrive/figures/porto/tip/in'
  import os
  image_dir='/content/drive/MyDrive/figures/porto/tip/in' # Directory of input images
  predict_colour_dir='/content/drive/MyDrive/figures/porto/tip/pred' # output maps directory.
  predict_colour_dir1='/content/drive/MyDrive/figures/porto/tip/pred1' # output maps directory.
  predict_colour_dir2='/content/drive/MyDrive/figures/porto/tip/pred2' # output maps directory.
  predict_colour_dir3='/content/drive/MyDrive/figures/porto/tip/pred3' # output maps directory.
  predict_colour_dir4='/content/drive/MyDrive/figures/porto/tip/pred4' # output maps directory.
  label_dir='/content/drive/MyDrive/figures/porto/tip/label' # labels directory fixed in one file.
  model.load_state_dict(torch.load(model_path))
  model=model.cuda()
  count=1
  with torch.no_grad():
    for j, (a,b) in enumerate(data_dl):
      a=a.float()
      pred,pred1,pred2,pred3=model(a.cuda())
      pred=pred.detach().cpu()
      pred1=pred1.detach().cpu()
      pred2=pred2.detach().cpu()
      pred3=pred3.detach().cpu()
      pred4=torch.nn.functional.interpolate(pred3, size=(32,32), scale_factor=None, mode='nearest')
      a=a*255.0
      a=a.detach().cpu()
      for i in range(pred1.shape[0]):
        image=np.array(a[i,0:3,:,:].permute(1,2,0)).astype(np.uint8)    # for RGB images
        pred00=np.array(((pred[i,0,:,:])*255.0)).astype(np.uint8)
        pred11=np.array(((pred1[i,0,:,:])*255.0)).astype(np.uint8)
        pred22=np.array(((pred2[i,0,:,:])*255.0)).astype(np.uint8)
        pred33=np.array(((pred3[i,0,:,:])*255.0)).astype(np.uint8)
        pred44=np.array(((pred4[i,0,:,:])*255.0)).astype(np.uint8)
        # print(pred00)
        # print(pred11)
        # print(pred22)
        # print(pred33)
        # print(pred44)

        _,_,_,lab=post_medical(b[i,0,:,:],b[i,0,:,:],512,512) # image height and width might change
        lab=np.array(lab).astype(np.uint8)
        image_filename=os.path.join(image_dir, f"input_{count}.tif")
        pred_colour_filename=os.path.join(predict_colour_dir, f"colour_{count}.png")
        pred_colour_filename1=os.path.join(predict_colour_dir1, f"colour_{count}.png")
        pred_colour_filename2=os.path.join(predict_colour_dir2, f"colour_{count}.png")
        pred_colour_filename3=os.path.join(predict_colour_dir3, f"colour_{count}.png")
        pred_colour_filename4=os.path.join(predict_colour_dir4, f"colour_{count}.png")
        label_filename=os.path.join(label_dir, f"label_{count}.png")
        cv2.imwrite(image_filename,image)
        cv2.imwrite(pred_colour_filename, pred00)
        cv2.imwrite(pred_colour_filename1, pred11)
        cv2.imwrite(pred_colour_filename2, pred22)
        cv2.imwrite(pred_colour_filename3, pred33)
        cv2.imwrite(pred_colour_filename4, pred44)
        cv2.imwrite(label_filename, lab)
        print("[DONE] predicted image: ", image_filename)
        print("[DONE] predicted image: ", pred_colour_filename)
        print("[DONE] predicted image: ", pred_colour_filename1)
        print("[DONE] predicted image: ", pred_colour_filename2)
        print("[DONE] predicted image: ", pred_colour_filename3)
        print("[DONE] predicted image: ", pred_colour_filename4)
        print("[DONE] predicted image: ", label_filename)
        count=count+1

# %%
test_dl = torch.utils.data.DataLoader(test_dataset, batch_size=15, shuffle=False, num_workers=2)
predict_mlsa(model,test_dl,model_path='/content/drive/MyDrive/weights/porto/tgrs/epoch13_test_dice0.7762')
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/figures/porto/tip/label’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/figures/porto/tip/in’: File exists
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_1.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_1.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_1.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_1.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_1.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_1.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_1.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_2.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_2.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_2.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_2.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_2.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_2.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_2.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_3.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_3.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_3.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_3.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_3.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_3.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_3.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_4.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_4.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_4.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_4.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_4.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_4.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_4.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_5.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_5.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_5.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_5.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_5.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_5.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_5.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_6.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_6.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_6.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_6.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_6.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_6.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_6.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_7.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_7.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_7.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_7.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_7.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_7.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_7.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_8.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_8.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_8.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_8.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_8.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_8.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_8.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_9.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_9.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_9.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_9.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_9.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_9.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_9.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_10.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_10.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_10.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_10.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_10.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_10.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_10.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_11.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_11.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_11.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_11.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_11.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_11.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_11.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_12.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_12.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_12.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_12.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_12.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_12.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_12.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_13.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_13.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_13.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_13.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_13.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_13.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_13.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_14.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_14.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_14.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_14.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_14.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_14.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_14.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_15.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_15.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_15.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_15.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_15.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_15.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_15.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_16.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_16.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_16.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_16.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_16.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_16.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_16.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_17.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_17.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_17.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_17.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_17.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_17.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_17.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_18.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_18.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_18.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_18.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_18.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_18.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_18.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_19.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_19.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_19.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_19.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_19.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_19.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_19.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_20.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_20.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_20.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_20.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_20.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_20.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_20.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_21.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_21.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_21.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_21.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_21.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_21.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_21.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_22.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_22.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_22.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_22.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_22.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_22.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_22.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_23.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_23.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_23.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_23.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_23.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_23.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_23.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_24.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_24.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_24.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_24.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_24.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_24.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_24.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_25.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_25.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_25.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_25.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_25.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_25.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_25.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_26.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_26.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_26.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_26.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_26.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_26.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_26.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_27.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_27.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_27.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_27.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_27.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_27.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_27.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_28.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_28.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_28.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_28.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_28.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_28.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_28.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_29.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_29.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_29.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_29.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_29.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_29.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_29.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_30.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_30.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_30.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_30.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_30.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_30.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_30.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_31.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_31.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_31.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_31.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_31.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_31.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_31.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_32.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_32.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_32.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_32.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_32.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_32.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_32.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_33.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_33.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_33.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_33.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_33.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_33.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_33.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_34.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_34.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_34.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_34.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_34.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_34.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_34.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_35.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_35.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_35.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_35.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_35.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_35.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_35.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_36.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_36.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_36.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_36.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_36.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_36.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_36.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_37.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_37.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_37.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_37.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_37.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_37.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_37.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_38.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_38.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_38.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_38.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_38.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_38.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_38.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_39.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_39.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_39.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_39.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_39.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_39.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_39.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_40.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_40.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_40.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_40.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_40.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_40.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_40.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_41.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_41.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_41.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_41.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_41.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_41.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_41.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_42.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_42.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_42.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_42.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_42.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_42.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_42.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_43.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_43.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_43.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_43.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_43.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_43.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_43.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_44.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_44.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_44.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_44.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_44.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_44.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_44.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_45.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_45.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_45.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_45.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_45.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_45.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_45.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_46.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_46.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_46.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_46.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_46.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_46.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_46.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_47.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_47.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_47.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_47.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_47.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_47.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_47.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_48.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_48.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_48.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_48.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_48.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_48.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_48.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_49.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_49.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_49.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_49.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_49.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_49.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_49.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_50.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_50.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_50.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_50.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_50.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_50.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_50.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_51.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_51.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_51.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_51.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_51.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_51.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_51.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_52.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_52.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_52.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_52.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_52.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_52.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_52.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_53.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_53.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_53.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_53.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_53.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_53.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_53.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_54.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_54.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_54.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_54.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_54.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_54.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_54.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_55.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_55.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_55.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_55.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_55.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_55.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_55.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_56.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_56.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_56.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_56.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_56.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_56.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_56.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_57.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_57.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_57.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_57.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_57.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_57.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_57.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_58.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_58.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_58.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_58.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_58.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_58.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_58.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_59.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_59.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_59.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_59.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_59.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_59.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_59.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_60.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_60.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_60.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_60.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_60.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_60.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_60.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_61.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_61.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_61.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_61.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_61.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_61.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_61.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_62.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_62.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_62.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_62.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_62.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_62.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_62.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_63.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_63.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_63.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_63.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_63.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_63.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_63.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_64.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_64.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_64.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_64.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_64.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_64.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_64.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_65.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_65.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_65.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_65.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_65.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_65.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_65.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_66.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_66.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_66.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_66.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_66.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_66.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_66.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_67.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_67.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_67.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_67.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_67.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_67.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_67.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_68.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_68.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_68.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_68.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_68.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_68.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_68.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_69.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_69.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_69.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_69.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_69.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_69.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_69.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_70.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_70.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_70.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_70.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_70.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_70.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_70.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_71.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_71.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_71.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_71.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_71.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_71.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_71.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_72.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_72.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_72.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_72.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_72.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_72.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_72.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_73.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_73.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_73.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_73.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_73.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_73.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_73.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_74.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_74.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_74.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_74.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_74.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_74.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_74.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_75.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_75.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_75.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_75.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_75.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_75.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_75.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_76.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_76.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_76.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_76.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_76.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_76.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_76.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_77.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_77.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_77.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_77.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_77.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_77.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_77.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_78.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_78.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_78.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_78.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_78.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_78.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_78.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_79.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_79.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_79.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_79.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_79.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_79.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_79.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_80.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_80.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_80.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_80.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_80.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_80.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_80.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_81.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_81.png
# ...
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_166.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_166.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_166.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_167.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_167.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_167.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_167.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_167.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_167.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_167.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_168.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_168.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_168.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_168.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_168.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_168.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_168.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_169.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_169.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_169.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_169.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_169.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_169.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_169.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_170.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_170.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_170.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_170.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_170.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_170.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_170.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_171.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_171.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_171.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_171.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_171.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_171.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_171.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_172.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_172.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_172.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_172.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_172.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_172.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_172.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_173.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_173.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_173.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_173.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_173.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_173.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_173.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_174.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_174.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_174.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_174.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_174.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_174.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_174.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_175.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_175.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_175.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_175.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_175.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_175.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_175.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_176.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_176.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_176.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_176.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_176.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_176.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_176.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_177.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_177.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_177.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_177.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_177.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_177.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_177.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_178.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_178.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_178.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_178.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_178.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_178.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_178.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_179.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_179.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_179.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_179.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_179.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_179.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_179.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_180.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_180.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_180.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_180.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_180.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_180.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_180.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_181.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_181.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_181.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_181.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_181.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_181.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_181.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_182.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_182.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_182.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_182.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_182.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_182.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_182.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_183.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_183.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_183.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_183.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_183.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_183.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_183.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_184.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_184.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_184.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_184.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_184.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_184.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_184.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_185.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_185.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_185.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_185.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_185.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_185.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_185.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_186.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_186.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_186.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_186.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_186.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_186.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_186.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_187.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_187.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_187.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_187.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_187.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_187.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_187.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_188.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_188.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_188.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_188.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_188.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_188.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_188.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_189.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_189.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_189.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_189.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_189.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_189.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_189.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_190.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_190.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_190.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_190.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_190.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_190.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_190.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_191.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_191.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_191.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_191.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_191.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_191.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_191.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/in/input_192.tif
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred/colour_192.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred1/colour_192.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred2/colour_192.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred3/colour_192.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/pred4/colour_192.png
# [DONE] predicted image:  /content/drive/MyDrive/figures/porto/tip/label/label_192.png
